# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('/Users/accountmanager/Desktop/Iron Hack/Unit_1/Labs and exercises/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')
df1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df1.shape
# Out:
# (10910, 26)

# %%
df1.columns = df1.columns.str.lower()
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df1.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
numeric_data = df1.select_dtypes(include=[np.number])
categorical_data = df1.select_dtypes(exclude=[np.number])

print(numeric_data.shape[1])
print(categorical_data.shape[1])
# Out:
# 9
# 17

# %%
df = df1.fillna('')
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
dft['effective to date'] = pd.to_datetime(df['effective to date'])
dft
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
# lab 3 starting here

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df.columns = df.columns.str.lower()
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df.shape
# Out:
# (10910, 26)

# %%
df.describe()
# Out:
#          unnamed: 0  customer lifetime value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly premium auto  months since policy inception  \
# count          10910.000000                   10910.000000
# mean              93.196059                      48.091934
# std               34.442532                      27.940675
# min               61.000000                       0.000000
# 25%               68.000000                      24.000000
# 50%               83.000000                      48.000000
# ...

# %%
df[df.columns].value_counts().hist()
plt.show()

# %%
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
nb_yes = df[df['response'] == 'Yes']['sales channel'].count()
nb_no = df[df['response'] == 'No']['sales channel'].count()
print(nb_yes)
print(nb_no)
# Out:
# 1466
# 8813

# %%
plt.figure(figsize=(16,8))

sns.countplot(data = df ,x = 'response')
plt.show()

# %%
plt.figure(figsize=(16,8))

sns.barplot(data = df ,x = "response", y = 'total claim amount')
plt.show()

# %%
plt.figure(figsize=(16,8))

sns.barplot(data = df , y = 'income',x = "response", hue='sales channel')
plt.show()

# %%
plt.scatter(df['response'], df['income'])
plt.show()

# %%
df.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim           object
# months since policy inception      int64
# number of open complaints         object
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
numerical = df[['unnamed: 0', 'customer lifetime value', 'income', 'monthly premium auto', 'months since policy inception', 'number of policies', 'total claim amount']]
numerical
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since policy inception  number of policies  total claim amount
# ...

# %%
sns.distplot(numerical['customer lifetime value'], bins=20)
plt.show()
sns.distplot(numerical['income'], bins=20)
plt.show()
sns.distplot(numerical['monthly premium auto'], bins=20)
plt.show()
sns.distplot(numerical['months since policy inception'], bins=20)
plt.show()
sns.distplot(numerical['number of policies'], bins=20)
plt.show()
sns.distplot(numerical['total claim amount'], bins=20)
plt.show()
# Out:
# /Users/accountmanager/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/accountmanager/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.hist(numerical['customer lifetime value'])
plt.show()
plt.hist(numerical['income'])
plt.show()
plt.hist(numerical['monthly premium auto'])
plt.show()
plt.hist(numerical['months since policy inception'])
plt.show()
plt.hist(numerical['number of policies'])
plt.show()
plt.hist(numerical['total claim amount'])
plt.show()

# %%
# not all of them, indeed they are some that follow the logic but for exemple the income one does not.
# There is a hole in the middle like if some informations were missing

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = numerical.columns
from statsmodels.stats.outliers_influence import variance_inflation_factor
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(numerical.values, i)
                          for i in range(len(numerical.columns))]
  
print(vif_data)
# Out:
#                          feature        VIF
# 0                     unnamed: 0   3.344423
# 1        customer lifetime value   2.820111
# 2                         income   2.870098
# 3           monthly premium auto  14.149598
# 4  months since policy inception   3.331701
# 5             number of policies   2.291192
# 6             total claim amount   6.663181

# %%
numerical.corr()
# Out:
#                                unnamed: 0  customer lifetime value    income  \
# unnamed: 0                       1.000000                 0.001355  0.008910
# customer lifetime value          0.001355                 1.000000  0.028306
# income                           0.008910                 0.028306  1.000000
# monthly premium auto             0.000863                 0.403069 -0.009788
# months since policy inception    0.012795                 0.016960 -0.005903
# number of policies               0.002319                 0.016024 -0.009960
# total claim amount              -0.000593                 0.232626 -0.354141
#
#                                monthly premium auto  \
# unnamed: 0                                 0.000863
# customer lifetime value                    0.403069
# income                                    -0.009788
# monthly premium auto                       1.000000
# months since policy inception              0.018953
# ...

# %%
# seems like none of the columns got a high correlation
